# %%
from sqlalchemy import create_engine
import pymysql
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
plt.style.use('ggplot')
db_connection_str = 'mysql+pymysql://root:@localhost/job_aggregator'
db_connection = create_engine(db_connection_str)

df = pd.read_sql('SELECT * from job', con=db_connection)
df
# Out:
#     id                                              title                                               link                     salary        location                job_type   job_category                                      job_office                            job_minimal_description   country job_time
# 0    1                                       Data Officer  https://www.brightermonday.co.ke/job/data-offi...           KSh Confidential         Nairobi               Full Time  IT & Software                        Tiny Totos Kenya Limited  We are currently looking for an data officer t...     Kenya      14h
# 1    2                                  Junior Programmer  https://www.brightermonday.co.ke/job/junior-pr...           KSh Confidential         Nairobi               Full Time  IT & Software                       Career Directions Limited  Our client would like to recruit a Junior prog...     Kenya       3d
# ...

# %%
kydf=df[df['country']=='Kenya']
kydf.head()
# Out:
#    id                                              title                                               link            salary       location   job_type   job_category                         job_office                            job_minimal_description country job_time
# 0   1                                       Data Officer  https://www.brightermonday.co.ke/job/data-offi...  KSh Confidential        Nairobi  Full Time  IT & Software           Tiny Totos Kenya Limited  We are currently looking for an data officer t...   Kenya      14h
# 1   2                                  Junior Programmer  https://www.brightermonday.co.ke/job/junior-pr...  KSh Confidential        Nairobi  Full Time  IT & Software          Career Directions Limited  Our client would like to recruit a Junior prog...   Kenya       3d
# ...

# %%
kydf=df[df['country']=='Tanzania']
kydf.head()
# Out:
#     id                                         title                                               link                     salary       location   job_type   job_category                       job_office                            job_minimal_description   country job_time
# 17  18  Short Term Data Entry Assistant NTD Programs  https://www.brightermonday.co.tz/job/short-ter...           TSh Confidential  Dar es Salaam  Full Time  IT & Software       Helen Keller International  Country Overview: Established in 1984, the HKI...  Tanzania       3d
# 18  19                              System Developer  https://www.brightermonday.co.tz/job/system-de...           TSh Confidential  Dar es Salaam  Full Time  IT & Software          Coseke Tanzania limited  Our Company is looking for a System Developer ...  Tanzania       2w
# ...

# %%
Ugdf=df[df['country']=='Uganda']
Ugdf.head()
# Out:
#     id                                   title                                               link            salary location   job_type   job_category                         job_office                            job_minimal_description country job_time
# 38  39                             IT Personal  https://www.brightermonday.co.ug/job/it-person...  USh Confidential  Kampala  Full Time  IT & Software  The African Talent Company | TATC  Designing and programming system-level softwar...  Uganda       1w
# 39  40       Information Technology I.T. Admin  https://www.brightermonday.co.ug/job/informati...  USh Confidential  Kampala  Full Time  IT & Software                 Anonymous Employer  The qualified the candidate will mainly help i...  Uganda       3w
# ...

# %%
NojobfCountry=df[['country','title']]
data=NojofCountry.groupby(['country'],as_index=False).count()
data
# Out:
#     country  title
# 0     Kenya     31
# 1  Tanzania      7
# 2    Uganda     16

# %%
jobTimedf=df[df['job_time']=='1mo']
jobTimedf
# Out:
#     id                            title                                               link                     salary       location   job_type   job_category                                      job_office                            job_minimal_description   country job_time
# 20  21   Solution (Technical) Architect  https://www.brightermonday.co.tz/job/solution-...  TSh 1,500,001 - 2,000,000  Dar es Salaam  Full Time  IT & Software                 Inventions Technologies Co. Ltd  Responsible for the technical analysis and hol...  Tanzania      1mo
# 22  23                 System Developer  https://www.brightermonday.co.tz/job/system-de...    TSh 500,001 - 1,000,000  Dar es Salaam  Full Time  IT & Software                       Dudumizi Technologies LTD  System developer will be responsible in develo...  Tanzania      1mo
# ...

# %%
# %matplotlib inline

# %%
df1 = df[['title','country']]
df1.groupby(['country'])['country'].count().plot.bar(color='b')
